# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from newsapi import NewsApiClient
load_dotenv()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\themi\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
# YOUR CODE HERE!
api_key = os.getenv("NEWS_API")

# %%
# Create a newsapi client
# YOUR CODE HERE!
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
# YOUR CODE HERE!
btc_headlines = newsapi.get_everything(q="bitcoin", language="en", sort_by="relevancy")
print(f"Total articles about Bitcoin: {btc_headlines['totalResults']}")
# Out:
# Total articles about Bitcoin: 9586

# %%
# Fetch the Ethereum news articles
# YOUR CODE HERE!
eth_headlines = newsapi.get_everything(q="ethereum", language="en", sort_by="relevancy")
print(f"Total articles about Ethereum: {eth_headlines['totalResults']}")
# Out:
# Total articles about Ethereum: 4527

# %%
# Create the Bitcoin sentiment scores DataFrame
# YOUR CODE HERE!
btc_sentiments = []

for article in btc_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        btc_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
btc_df = pd.DataFrame(btc_sentiments)

# Reorder DataFrame columns
cols = ["date", "compound", "positive", "negative", "neutral", "text"]
btc_df = btc_df[cols]

btc_df.head()
# Out:
#          date  compound  positive  negative  neutral  \
# 0  2022-06-03   -0.5574     0.000     0.098    0.902
# 1  2022-05-10    0.0772     0.036     0.000    0.964
# 2  2022-06-08    0.5267     0.124     0.000    0.876
# 3  2022-06-05    0.5106     0.164     0.000    0.836
# 4  2022-06-02   -0.1027     0.000     0.040    0.960
#
#                                                 text
# 0  New York lawmakers have passed a bill\r\n that...
# 1  Now, even though there are a number of women-f...
# 2  A new study on bitcoin calls into question whe...
# 3  Image caption, President Faustin-Archange Toua...
# 4  You can now reportedly pay for your burritos a...

# %%
# Create the Ethereum sentiment scores DataFrame
# YOUR CODE HERE!
eth_sentiments = []

for article in eth_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        eth_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
eth_df = pd.DataFrame(eth_sentiments)

# Reorder DataFrame columns
cols = ["date", "compound", "positive", "negative", "neutral", "text"]
eth_df = eth_df[cols]

eth_df.head()
# Out:
#          date  compound  positive  negative  neutral  \
# 0  2022-05-10    0.6486     0.135     0.000    0.865
# 1  2022-05-23   -0.1027     0.000     0.040    0.960
# 2  2022-06-07    0.3182     0.059     0.000    0.941
# 3  2022-05-23    0.1280     0.046     0.000    0.954
# 4  2022-06-03   -0.5574     0.000     0.098    0.902
#
#                                                 text
# 0  Meta has revealed more of how NFTs will work o...
# 1  GameStop has officially thrown itself headlong...
# 2  The ability to conduct external transfers on P...
# 3  GameStop is going all-in on crypto. The video ...
# 4  New York lawmakers have passed a bill\r\n that...

# %%
# Describe the Bitcoin Sentiment
# YOUR CODE HERE!
btc_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean   -0.087630   0.048200   0.065450   0.886450
# std     0.403464   0.049645   0.069041   0.073103
# min    -0.859300   0.000000   0.000000   0.646000
# 25%    -0.386825   0.000000   0.000000   0.858000
# 50%    -0.051350   0.041500   0.063000   0.888500
# 75%     0.249275   0.077500   0.087500   0.924250
# max     0.526700   0.164000   0.300000   1.000000

# %%
# Describe the Ethereum Sentiment
# YOUR CODE HERE!
eth_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean   -0.008160   0.041350   0.040550   0.918200
# std     0.398847   0.051657   0.049995   0.052626
# min    -0.690800   0.000000   0.000000   0.822000
# 25%    -0.381800   0.000000   0.000000   0.891250
# 50%     0.000000   0.017000   0.020000   0.924000
# 75%     0.323650   0.072750   0.077000   0.955000
# max     0.690800   0.178000   0.178000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin at .048 while ETH was lower at .041
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum at max .69 versus BTC lower at max .52
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum at .178 vs BTC lower at .164

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
# YOUR CODE HERE!
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
# YOUR CODE HERE!
sw = set(stopwords.words('english'))


# Expand the default stopwords list if necessary
# YOUR CODE HERE!
sw_addon = {'ha', 'charsnow', 'charsthe', 'ano','depp'}

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    # Remove the punctuation from text
    # Create a tokenized list of the words
    # Lemmatize words into root words
    # Convert the words to lowercase
    # Remove the stop words
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    #tokens = [word.lower() for word in lem if word.lower() not in sw]
    tokens = [word.lower() for word in words if word.lower() not in sw.union(sw_addon)]
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
# YOUR CODE HERE!
btc_df["tokens"] = btc_df["text"].apply(tokenizer)
btc_df.head()
# Out:
#          date  compound  positive  negative  neutral  \
# 0  2022-06-03   -0.5574     0.000     0.098    0.902
# 1  2022-05-10    0.0772     0.036     0.000    0.964
# 2  2022-06-08    0.5267     0.124     0.000    0.876
# 3  2022-06-05    0.5106     0.164     0.000    0.836
# 4  2022-06-02   -0.1027     0.000     0.040    0.960
#
#                                                 text  \
# 0  New York lawmakers have passed a bill\r\n that...
# 1  Now, even though there are a number of women-f...
# 2  A new study on bitcoin calls into question whe...
# 3  Image caption, President Faustin-Archange Toua...
# 4  You can now reportedly pay for your burritos a...
#
#                                               tokens
# 0  [new, york, lawmakers, passed, bill, would, te...
# 1  [even, though, number, womenfocused, crypto, s...
# 2  [new, study, bitcoin, calls, question, whether...
# 3  [image, caption, president, faustinarchange, t...
# 4  [reportedly, pay, burritos, tacos, bitcoin, di...

# %%
# Create a new tokens column for Ethereum
# YOUR CODE HERE!
eth_df["tokens"] = eth_df["text"].apply(tokenizer)
eth_df.head()
# Out:
#          date  compound  positive  negative  neutral  \
# 0  2022-05-10    0.6486     0.135     0.000    0.865
# 1  2022-05-23   -0.1027     0.000     0.040    0.960
# 2  2022-06-07    0.3182     0.059     0.000    0.941
# 3  2022-05-23    0.1280     0.046     0.000    0.954
# 4  2022-06-03   -0.5574     0.000     0.098    0.902
#
#                                                 text  \
# 0  Meta has revealed more of how NFTs will work o...
# 1  GameStop has officially thrown itself headlong...
# 2  The ability to conduct external transfers on P...
# 3  GameStop is going all-in on crypto. The video ...
# 4  New York lawmakers have passed a bill\r\n that...
#
#                                               tokens
# 0  [meta, revealed, nfts, work, instagram, usbase...
# 1  [gamestop, officially, thrown, headlong, web, ...
# 2  [ability, conduct, external, transfers, paypal...
# 3  [gamestop, going, allin, crypto, video, game, ...
# 4  [new, york, lawmakers, passed, bill, would, te...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Code from office hours - loop not needed #
#tokens = []
#for i in range(btc_df.shape[0]):
    #tokens += btc_df.iloc[i]["text"]

# %%
# Generate the Bitcoin N-grams where N=2
# YOUR CODE HERE!
btc_tokens = tokenizer(btc_df["text"].str.cat()) #convert to string to prevent error
btc_counts = Counter(ngrams(btc_tokens, n=2))
btc_counts
# Out:
# Counter({('new', 'york'): 1,
#          ('york', 'lawmakers'): 1,
#          ('lawmakers', 'passed'): 1,
#          ('passed', 'bill'): 1,
#          ('bill', 'would'): 1,
#          ('would', 'temporarily'): 1,
#          ('temporarily', 'ban'): 1,
#          ('ban', 'new'): 1,
#          ('new', 'bitcoin'): 1,
#          ('bitcoin', 'mining'): 1,
#          ('mining', 'operations'): 1,
#          ('operations', 'early'): 1,
#          ('early', 'friday'): 1,
#          ('friday', 'state'): 1,
#          ('state', 'senators'): 1,
#          ('senators', 'voted'): 1,
#          ('voted', 'pass'): 1,
#          ('pass', 'legislation'): 1,
#          ('legislation', 'bound'): 1,
#          ('bound', 'desk'): 1,
#          ('desk', 'even'): 1,
#          ('even', 'though'): 1,
#          ('though', 'number'): 1,
#          ('number', 'womenfocused'): 1,
#          ('womenfocused', 'crypto'): 1,
#          ('crypto', 'spaces'): 1,
#          ('spaces', 'odeniran'): 1,
#          ('odeniran', 'says'): 1,
#          ('says', 'women'): 1,
#          ('women', 'still'): 1,
#          ('still', 'underrepresented'): 1,
#          ('underrepresented', 'ive'): 1,
#          ('ive', 'spaces'): 1,
#          ('spaces', 'im'): 1,
#          ('im', 'black'): 1,
#          ('black', 'person'): 1,
#          ('person', 'woman'): 1,
#          ('woman', 'b'): 1,
#          ('b', 'charsa'): 1,
#          ('charsa', 'new'): 1,
#          ('new', 'study'): 1,
#          ('study', 'bitcoin'): 1,
#          ('bitcoin', 'calls'): 1,
#          ('calls', 'question'): 1,
#          ('question', 'whether'): 1,
#          ('whether', 'digital'): 1,
#          ('digital', 'currency'): 1,
#          ('currency', 'truly'): 1,
#          ('truly', 'decentralized'): 1,
#          ('decentralized', 'anonymous'): 1,
#          ('anonymous', 'biggest'): 1,
#          ('biggest', 'devotees'): 1,
#          ('devotees', 'would'): 1,
#          ('would', 'believe'): 1,
#          ('believe', 'researchers'): 1,
#          ('researchers', 'baylor'): 1,
#          ('baylor', 'rice'): 1,
#          ('rice', 'charsimage'): 1,
#          ('charsimage', 'caption'): 1,
#          ('caption', 'president'): 1,
#          ('president', 'faustinarchange'): 1,
#          ('faustinarchange', 'touadra'): 1,
#          ('touadra', 'wants'): 1,
#          ('wants', 'rethink'): 1,
#          ('rethink', 'countrys'): 1,
#          ('countrys', 'economic'): 1,
#          ('economic', 'philosophythe'): 1,
#          ('philosophythe', 'central'): 1,
#          ('central', 'african'): 1,
#          ('african', 'republics'): 1,
#          ('republics', 'decision'): 1,
#          ('decision', 'adopt'): 1,
#          ('adopt', 'bitcoin'): 1,
#          ('bitcoin', 'legal'): 1,
#          ('legal', 'tender'): 1,
#          ('tender', 'came'): 1,
#          ('came', 'surprise'): 1,
#          ('surprise', 'charsyou'): 1,
#          ('charsyou', 'reportedly'): 1,
#          ('reportedly', 'pay'): 1,
#          ('pay', 'burritos'): 2,
#          ('burritos', 'tacos'): 1,
#          ('tacos', 'bitcoin'): 1,
#          ('bitcoin', 'digital'): 1,
#          ('digital', 'currencies'): 1,
#          ('currencies', 'case'): 1,
#          ('case', 'dont'): 1,
#          ('dont', 'mind'): 1,
#          ('mind', 'spending'): 1,
#          ('spending', 'coins'): 1,
#          ('coins', 'directly'): 1,
#          ('directly', 'instead'): 1,
#          ('instead', 'going'): 1,
#          ('going', 'exchanges'): 1,
#          ('exchanges', 'first'): 1,
#          ('first', 'flexa'): 1,
#          ('flexa', 'h'): 1,
#          ('h', 'charsimage'): 1,
#          ('charsimage', 'source'): 1,
#          ('source', 'getty'): 1,
#          ('getty', 'imagesthe'): 1,
#          ('imagesthe', 'value'): 1,
#          ('value', 'bitcoin'): 1,
#          ('bitcoin', 'continued'): 1,
#          ('continued', 'fall'): 1,
#          ('fall', 'weekend'): 1,
#          ('weekend', 'dropped'): 1,
#          ('dropped', 'according'): 1,
#          ('according', 'coinbase'): 1,
#          ('coinbase', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'exchangethe'): 1,
#          ('exchangethe', 'worlds'): 1,
#          ('worlds', 'largest'): 1,
#          ('largest', 'cryp'): 1,
#          ('cryp', 'charsas'): 1,
#          ('charsas', 'kid'): 1,
#          ('kid', 'remember'): 1,
#          ('remember', 'father'): 1,
#          ('father', 'tried'): 1,
#          ('tried', 'use'): 1,
#          ('use', 'broom'): 1,
#          ('broom', 'handle'): 1,
#          ('handle', 'last'): 1,
#          ('last', 'ditch'): 1,
#          ('ditch', 'effort'): 1,
#          ('effort', 'support'): 1,
#          ('support', 'roof'): 1,
#          ('roof', 'collapsing'): 1,
#          ('collapsing', 'weight'): 1,
#          ('weight', 'nearly'): 1,
#          ('nearly', 'three'): 1,
#          ('three', 'feet'): 1,
#          ('feet', 'snow'): 1,
#          ('snow', 'guess'): 1,
#          ('guess', 'well'): 1,
#          ('well', 'charscustomers'): 1,
#          ('charscustomers', 'chipotle'): 1,
#          ('chipotle', 'able'): 1,
#          ('able', 'pay'): 1,
#          ('burritos', 'cryptocurrencies'): 1,
#          ('cryptocurrencies', 'including'): 1,
#          ('including', 'bitcoin'): 1,
#          ('bitcoin', 'ether'): 1,
#          ('ether', 'dogecoin'): 1,
#          ('dogecoin', 'move'): 1,
#          ('move', 'could'): 1,
#          ('could', 'help'): 1,
#          ('help', 'crypto'): 1,
#          ('crypto', 'become'): 1,
#          ('become', 'mainstream'): 1,
#          ('mainstream', 'according'): 1,
#          ('according', 'charsphoto'): 1,
#          ('charsphoto', 'illustration'): 1,
#          ('illustration', 'grayson'): 1,
#          ('grayson', 'blackmon'): 1,
#          ('blackmon', 'verge'): 1,
#          ('verge', 'photo'): 1,
#          ('photo', 'oliyarnyk'): 1,
#          ('oliyarnyk', 'ccbysa'): 1,
#          ('ccbysa', 'michael'): 1,
#          ('michael', 'chobanian'): 1,
#          ('chobanian', 'president'): 1,
#          ('president', 'blockchain'): 1,
#          ('blockchain', 'association'): 1,
#          ('association', 'ukraine'): 1,
#          ('ukraine', 'terrible'): 1,
#          ('terrible', 'unprovoked'): 1,
#          ('unprovoked', 'wa'): 1,
#          ('wa', 'charsposted'): 1,
#          ('charsposted', 'bitcoins'): 1,
#          ('bitcoins', 'dramatic'): 1,
#          ('dramatic', 'drop'): 1,
#          ('drop', 'new'): 1,
#          ('new', 'way'): 1,
#          ('way', 'pay'): 1,
#          ('pay', 'luxury'): 1,
#          ('luxury', 'gucci'): 1,
#          ('gucci', 'handbag'): 1,
#          ('handbag', 'round'): 1,
#          ('round', 'weeks'): 1,
#          ('weeks', 'big'): 1,
#          ('big', 'stories'): 1,
#          ('stories', 'cryptocurrencies'): 1,
#          ('cryptocurrencies', 'kristy'): 1,
#          ('kristy', 'kilburn'): 1,
#          ('kilburn', 'reportsmay'): 1,
#          ('reportsmay', 'reuters'): 1,
#          ('reuters', 'bitcoin'): 4,
#          ('bitcoin', 'fell'): 1,
#          ('fell', 'gmt'): 1,
#          ('gmt', 'wednesday'): 1,
#          ('wednesday', 'losing'): 1,
#          ('losing', 'previous'): 2,
#          ('previous', 'closebitcoin'): 2,
#          ('closebitcoin', 'worlds'): 2,
#          ('worlds', 'biggest'): 3,
#          ('biggest', 'bestknown'): 3,
#          ('bestknown', 'cryptocurrency'): 3,
#          ('cryptocurrency', 'fro'): 1,
#          ('fro', 'charsmay'): 1,
#          ('charsmay', 'reuters'): 3,
#          ('bitcoin', 'dropped'): 1,
#          ('dropped', 'gmt'): 1,
#          ('gmt', 'monday'): 2,
#          ('monday', 'losing'): 1,
#          ('cryptocurrency', 'charsjune'): 1,
#          ('charsjune', 'reuters'): 1,
#          ('bitcoin', 'rose'): 1,
#          ('rose', 'gmt'): 1,
#          ('monday', 'adding'): 1,
#          ('adding', 'previous'): 1,
#          ('previous', 'closethe'): 1,
#          ('closethe', 'worlds'): 1,
#          ('cryptocurrency', 'years'): 1,
#          ('years', 'high'): 1,
#          ('high', 'charsbtc'): 1,
#          ('charsbtc', 'fell'): 1,
#          ('fell', 'lowest'): 1,
#          ('lowest', 'level'): 1,
#          ('level', 'since'): 1,
#          ('since', 'last'): 1,
#          ('last', 'july'): 1,
#          ('july', 'prices'): 1,
#          ('prices', 'dropped'): 1,
#          ('dropped', 'start'): 1,
#          ('start', 'week'): 1,
#          ('week', 'selloff'): 1,
#          ('selloff', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'started'): 1,
#          ('started', 'last'): 1,
#          ('last', 'week'): 1,
#          ('week', 'following'): 1,
#          ('following', 'feds'): 1,
#          ('feds', 'decision'): 1,
#          ('decision', 'hike'): 1,
#          ('hike', 'interest'): 1,
#          ('interest', 'rates'): 2,
#          ('rates', 'b'): 1,
#          ('b', 'charsat'): 1,
#          ('charsat', 'mexican'): 1,
#          ('mexican', 'restaurant'): 1,
#          ('restaurant', 'north'): 1,
#          ('north', 'london'): 1,
#          ('london', 'weeks'): 1,
#          ('weeks', 'ago'): 1,
#          ('ago', 'handful'): 1,
#          ('handful', 'smalltime'): 1,
#          ('smalltime', 'remarkably'): 1,
#          ('remarkably', 'discerning'): 1,
#          ('discerning', 'retail'): 1,
#          ('retail', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'investors'): 1,
#          ('investors', 'predicted'): 1,
#          ('predicted', 'terra'): 1,
#          ('terra', 'luna'): 1,
#          ('luna', 'would'): 1,
#          ('would', 'crash'): 1,
#          ('crash', 'several'): 1,
#          ('several', 'w'): 1,
#          ('w', 'charsmay'): 1,
#          ('reuters', 'crypto'): 1,
#          ('crypto', 'winter'): 1,
#          ('winter', 'ninth'): 1,
#          ('ninth', 'week'): 1,
#          ('week', 'bitcoin'): 1,
#          ('bitcoin', 'cant'): 1,
#          ('cant', 'shake'): 1,
#          ('shake', 'chillsfrom'): 1,
#          ('chillsfrom', 'technicals'): 1,
#          ('technicals', 'turnover'): 1,
#          ('turnover', 'market'): 1,
#          ('market', 'indicators'): 1,
#          ('indicators', 'flashing'): 1,
#          ('flashing', 'red'): 1,
#          ('red', 'amber'): 1,
#          ('amber', 'biggest'): 1,
#          ('biggest', 'cryptocurrenc'): 1,
#          ('cryptocurrenc', 'charsmay'): 1,
#          ('bitcoin', 'scant'): 1,
#          ('scant', 'experience'): 1,
#          ('experience', 'rising'): 1,
#          ('rising', 'interest'): 1,
#          ('rates', 'posing'): 1,
#          ('posing', 'perils'): 1,
#          ('perils', 'investors'): 1,
#          ('investors', 'looking'): 1,
#          ('looking', 'capitalize'): 1,
#          ('capitalize', 'dramatic'): 1,
#          ('dramatic', 'dropthe'): 1,
#          ('dropthe', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'tanked'): 1,
#          ('tanked', 'along'): 1,
#          ('along', 'ris'): 1,
#          ('ris', 'charsterra'): 1,
#          ('charsterra', 'launching'): 1,
#          ('launching', 'new'): 1,
#          ('new', 'blockchain'): 3,
#          ('blockchain', 'new'): 2,
#          ('new', 'luna'): 2,
#          ('luna', 'token'): 2,
#          ('token', 'seth'): 1,
#          ('seth', 'greens'): 3,
#          ('greens', 'animated'): 2,
#          ('animated', 'show'): 2,
#          ('show', 'starring'): 2,
#          ('starring', 'stolen'): 2,
#          ('stolen', 'nft'): 2,
#          ('nft', 'air'): 2,
#          ('air', 'largest'): 2,
#          ('largest', 'stablecoin'): 2,
#          ('stablecoin', 'issuer'): 2,
#          ('issuer', 'world'): 2,
#          ('world', 'launched'): 2,
#          ('launched', 'token'): 2,
#          ('token', 'mex'): 1,
#          ('mex', 'charsterra'): 1,
#          ('charsterra', 'launched'): 1,
#          ('launched', 'new'): 1,
#          ('token', 'today'): 1,
#          ('today', 'seth'): 1,
#          ('token', 'charsafter'): 1,
#          ('charsafter', 'two'): 1,
#          ('two', 'linked'): 1,
#          ('linked', 'cryptocurrencies'): 1,
#          ('cryptocurrencies', 'collapsed'): 1,
#          ('collapsed', 'became'): 1,
#          ('became', 'almost'): 1,
#          ('almost', 'worthless'): 1,
#          ('worthless', 'plan'): 1,
#          ('plan', 'emerged'): 1,
#          ('emerged', 'create'): 1,
#          ('create', 'new'): 1,
#          ('blockchain', 'luna'): 1,
#          ('luna', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'seth'): 1,
#          ('greens', 'nfts'): 1,
#          ('nfts', 'stolen'): 1,
#          ('stolen', 'phishing'): 1,
#          ('phishing', 'scam'): 1,
#          ('scam', 'nike'): 1,
#          ('nike', 'chars'): 1})

# %%
# Generate the Ethereum N-grams where N=2
# YOUR CODE HERE!
eth_tokens = tokenizer(eth_df["text"].str.cat()) #convert to string to prevent error
eth_counts = Counter(ngrams(eth_tokens, n=2))
eth_counts
# Out:
# Counter({('meta', 'revealed'): 1,
#          ('revealed', 'nfts'): 1,
#          ('nfts', 'work'): 1,
#          ('work', 'instagram'): 1,
#          ('instagram', 'usbased'): 1,
#          ('usbased', 'test'): 1,
#          ('test', 'show'): 1,
#          ('show', 'youve'): 1,
#          ('youve', 'bought'): 1,
#          ('bought', 'created'): 1,
#          ('created', 'free'): 1,
#          ('free', 'connecting'): 1,
#          ('connecting', 'instagram'): 1,
#          ('instagram', 'account'): 1,
#          ('account', 'compatible'): 1,
#          ('compatible', 'digital'): 1,
#          ('digital', 'walle'): 1,
#          ('walle', 'charsgamestop'): 1,
#          ('charsgamestop', 'officially'): 1,
#          ('officially', 'thrown'): 1,
#          ('thrown', 'headlong'): 1,
#          ('headlong', 'web'): 1,
#          ('web', 'vipers'): 1,
#          ('vipers', 'nest'): 1,
#          ('nest', 'new'): 1,
#          ('new', 'app'): 1,
#          ('app', 'release'): 1,
#          ('release', 'though'): 1,
#          ('though', 'hard'): 1,
#          ('hard', 'say'): 1,
#          ('say', 'whether'): 1,
#          ('whether', 'proposed'): 1,
#          ('proposed', 'population'): 1,
#          ('population', 'gamers'): 1,
#          ('gamers', 'game'): 1,
#          ('game', 'developers'): 1,
#          ('developers', 'take'): 1,
#          ('take', 'ability'): 1,
#          ('ability', 'conduct'): 1,
#          ('conduct', 'external'): 1,
#          ('external', 'transfers'): 1,
#          ('transfers', 'paypals'): 1,
#          ('paypals', 'crypto'): 1,
#          ('crypto', 'platform'): 1,
#          ('platform', 'image'): 1,
#          ('image', 'seen'): 1,
#          ('seen', 'start'): 1,
#          ('start', 'rolling'): 1,
#          ('rolling', 'users'): 1,
#          ('users', 'today'): 1,
#          ('today', 'available'): 1,
#          ('available', 'everyone'): 1,
#          ('everyone', 'us'): 1,
#          ('us', 'next'): 1,
#          ('next', 'charsgamestop'): 1,
#          ('charsgamestop', 'going'): 1,
#          ('going', 'allin'): 1,
#          ('allin', 'crypto'): 1,
#          ('crypto', 'video'): 1,
#          ('video', 'game'): 1,
#          ('game', 'retailer'): 1,
#          ('retailer', 'launchedits'): 1,
#          ('launchedits', 'selfcustodial'): 1,
#          ('selfcustodial', 'ethereum'): 1,
#          ('ethereum', 'digital'): 1,
#          ('digital', 'wallet'): 1,
#          ('wallet', 'said'): 1,
#          ('said', 'monday'): 1,
#          ('monday', 'wallet'): 1,
#          ('wallet', 'accessible'): 1,
#          ('accessible', 'google'): 1,
#          ('google', 'chrome'): 1,
#          ('chrome', 'extension'): 1,
#          ('extension', 'charsnew'): 1,
#          ('charsnew', 'york'): 1,
#          ('york', 'lawmakers'): 1,
#          ('lawmakers', 'passed'): 1,
#          ('passed', 'bill'): 1,
#          ('bill', 'would'): 1,
#          ('would', 'temporarily'): 1,
#          ('temporarily', 'ban'): 1,
#          ('ban', 'new'): 1,
#          ('new', 'bitcoin'): 1,
#          ('bitcoin', 'mining'): 1,
#          ('mining', 'operations'): 1,
#          ('operations', 'early'): 1,
#          ('early', 'friday'): 1,
#          ('friday', 'state'): 1,
#          ('state', 'senators'): 1,
#          ('senators', 'voted'): 1,
#          ('voted', 'pass'): 1,
#          ('pass', 'legislation'): 1,
#          ('legislation', 'bound'): 1,
#          ('bound', 'desk'): 1,
#          ('desk', 'charsdavos'): 1,
#          ('charsdavos', 'switzerland'): 1,
#          ('switzerland', 'may'): 1,
#          ('may', 'reuters'): 1,
#          ('reuters', 'ethereums'): 1,
#          ('ethereums', 'cofounder'): 1,
#          ('cofounder', 'gavin'): 1,
#          ('gavin', 'wood'): 1,
#          ('wood', 'said'): 1,
#          ('said', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'investors'): 1,
#          ('investors', 'need'): 1,
#          ('need', 'aware'): 1,
#          ('aware', 'backing'): 1,
#          ('backing', 'holdings'): 1,
#          ('holdings', 'market'): 1,
#          ('market', 'rout'): 1,
#          ('rout', 'wiped'): 1,
#          ('wiped', 'charseditorial'): 1,
#          ('charseditorial', 'independencewe'): 1,
#          ('independencewe', 'want'): 1,
#          ('want', 'help'): 1,
#          ('help', 'make'): 1,
#          ('make', 'informed'): 1,
#          ('informed', 'decisions'): 1,
#          ('decisions', 'links'): 1,
#          ('links', 'page'): 1,
#          ('page', 'clearly'): 1,
#          ('clearly', 'marked'): 1,
#          ('marked', 'may'): 1,
#          ('may', 'take'): 1,
#          ('take', 'partner'): 1,
#          ('partner', 'website'): 1,
#          ('website', 'may'): 1,
#          ('may', 'result'): 1,
#          ('result', 'us'): 1,
#          ('us', 'earning'): 1,
#          ('earning', 'referral'): 1,
#          ('referral', 'commission'): 1,
#          ('commission', 'fo'): 1,
#          ('fo', 'chars'): 1,
#          ('chars', 'days'): 1,
#          ('days', 'ago'): 1,
#          ('ago', 'bitcoin'): 1,
#          ('bitcoin', 'sold'): 1,
#          ('sold', 'price'): 1,
#          ('price', 'drop'): 1,
#          ('drop', 'third'): 1,
#          ('third', 'drop'): 1,
#          ('drop', 'happened'): 1,
#          ('happened', 'week'): 1,
#          ('week', 'bitcoin'): 1,
#          ('bitcoin', 'ethereum'): 1,
#          ('ethereum', 'major'): 1,
#          ('major', 'cryptocurrencies'): 1,
#          ('cryptocurrencies', 'fallen'): 1,
#          ('fallen', 'sharp'): 1,
#          ('sharp', 'charswhen'): 1,
#          ('charswhen', 'nvidia'): 1,
#          ('nvidia', 'launched'): 1,
#          ('launched', 'ampere'): 1,
#          ('ampere', 'lite'): 1,
#          ('lite', 'hash'): 2,
#          ('hash', 'rate'): 2,
#          ('rate', 'lhr'): 1,
#          ('lhr', 'graphics'): 1,
#          ('graphics', 'card'): 1,
#          ('card', 'feared'): 1,
#          ('feared', 'ethereum'): 1,
#          ('ethereum', 'antimining'): 1,
#          ('antimining', 'limiter'): 1,
#          ('limiter', 'world'): 1,
#          ('world', 'knew'): 1,
#          ('knew', 'matter'): 1,
#          ('matter', 'time'): 1,
#          ('time', 'someone'): 1,
#          ('someone', 'team'): 1,
#          ('team', 'cracked'): 1,
#          ('cracked', 'niceh'): 1,
#          ('niceh', 'charsmay'): 1,
#          ('charsmay', 'reuters'): 2,
#          ('reuters', 'bitcoin'): 3,
#          ('bitcoin', 'fell'): 1,
#          ('fell', 'gmt'): 1,
#          ('gmt', 'wednesday'): 1,
#          ('wednesday', 'losing'): 1,
#          ('losing', 'previous'): 2,
#          ('previous', 'closebitcoin'): 2,
#          ('closebitcoin', 'worlds'): 2,
#          ('worlds', 'biggest'): 3,
#          ('biggest', 'bestknown'): 3,
#          ('bestknown', 'cryptocurrency'): 3,
#          ('cryptocurrency', 'fro'): 1,
#          ('fro', 'charsmay'): 1,
#          ('bitcoin', 'dropped'): 1,
#          ('dropped', 'gmt'): 1,
#          ('gmt', 'monday'): 2,
#          ('monday', 'losing'): 1,
#          ('cryptocurrency', 'charsjune'): 1,
#          ('charsjune', 'reuters'): 1,
#          ('bitcoin', 'rose'): 1,
#          ('rose', 'gmt'): 1,
#          ('monday', 'adding'): 1,
#          ('adding', 'previous'): 1,
#          ('previous', 'closethe'): 1,
#          ('closethe', 'worlds'): 1,
#          ('cryptocurrency', 'years'): 1,
#          ('years', 'high'): 1,
#          ('high', 'chars'): 1,
#          ('chars', 'posters'): 1,
#          ('posters', 'participatingnvidia'): 1,
#          ('participatingnvidia', 'began'): 1,
#          ('began', 'releasing'): 1,
#          ('releasing', 'lhr'): 1,
#          ('lhr', 'lite'): 1,
#          ('rate', 'graphics'): 1,
#          ('graphics', 'cards'): 1,
#          ('cards', 'last'): 1,
#          ('last', 'yearto'): 1,
#          ('yearto', 'slow'): 1,
#          ('slow', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'mining'): 1,
#          ('mining', 'performance'): 1,
#          ('performance', 'make'): 1,
#          ('make', 'less'): 1,
#          ('less', 'appealing'): 1,
#          ('appealing', 'nongamers'): 1,
#          ('nongamers', 'charsbtc'): 1,
#          ('charsbtc', 'fell'): 1,
#          ('fell', 'lowest'): 1,
#          ('lowest', 'level'): 1,
#          ('level', 'since'): 1,
#          ('since', 'last'): 1,
#          ('last', 'july'): 1,
#          ('july', 'prices'): 1,
#          ('prices', 'dropped'): 1,
#          ('dropped', 'start'): 1,
#          ('start', 'week'): 1,
#          ('week', 'selloff'): 1,
#          ('selloff', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'started'): 1,
#          ('started', 'last'): 1,
#          ('last', 'week'): 1,
#          ('week', 'following'): 1,
#          ('following', 'feds'): 1,
#          ('feds', 'decision'): 1,
#          ('decision', 'hike'): 1,
#          ('hike', 'interest'): 1,
#          ('interest', 'rates'): 1,
#          ('rates', 'b'): 1,
#          ('b', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'boom'): 2,
#          ('boom', 'past'): 2,
#          ('past', 'years'): 2,
#          ('years', 'helped'): 2,
#          ('helped', 'propel'): 2,
#          ('propel', 'newer'): 2,
#          ('newer', 'market'): 2,
#          ('market', 'record'): 2,
#          ('record', 'heights'): 2,
#          ('heights', 'digital'): 2,
#          ('digital', 'collectibles'): 2,
#          ('collectibles', 'known'): 2,
#          ('known', 'nftsthe'): 2,
#          ('nftsthe', 'craze'): 2,
#          ('craze', 'pushed'): 2,
#          ('pushed', 'total'): 2,
#          ('total', 'nft'): 2,
#          ('nft', 'sales'): 2,
#          ('sales', 'volume'): 2,
#          ('volume', 'billion'): 2,
#          ('billion', 'ov'): 2,
#          ('ov', 'charswe'): 1,
#          ('charswe', 'first'): 1,
#          ('first', 'heard'): 1,
#          ('heard', 'potential'): 1,
#          ('potential', 'blockchain'): 1,
#          ('blockchain', 'supply'): 1,
#          ('supply', 'chains'): 1,
#          ('chains', 'several'): 1,
#          ('several', 'years'): 1,
#          ('years', 'ago'): 1,
#          ('ago', 'almost'): 1,
#          ('almost', 'immediately'): 1,
#          ('immediately', 'thrust'): 1,
#          ('thrust', 'cycle'): 1,
#          ('cycle', 'hype'): 1,
#          ('hype', 'hope'): 1,
#          ('hope', 'could'): 1,
#          ('could', 'us'): 1,
#          ('us', 'followed'): 1,
#          ('followed', 'trou'): 1,
#          ('trou', 'charsevery'): 1,
#          ('charsevery', 'time'): 1,
#          ('time', 'turn'): 1,
#          ('turn', 'around'): 1,
#          ('around', 'seems'): 1,
#          ('seems', 'another'): 1,
#          ('another', 'celebrity'): 1,
#          ('celebrity', 'hawking'): 1,
#          ('hawking', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'nfts'): 1,
#          ('nfts', 'influencer'): 1,
#          ('influencer', 'kim'): 1,
#          ('kim', 'kardashian'): 1,
#          ('kardashian', 'boxer'): 1,
#          ('boxer', 'floyd'): 1,
#          ('floyd', 'mayweather'): 1,
#          ('mayweather', 'former'): 1,
#          ('former', 'nba'): 1,
#          ('nba', 'athlete'): 1,
#          ('athlete', 'paul'): 1,
#          ('paul', 'pierce'): 1,
#          ('pierce', 'promoted'): 1,
#          ('promoted', 'ether'): 1,
#          ('ether', 'charsimage'): 1,
#          ('charsimage', 'source'): 1,
#          ('source', 'getty'): 1,
#          ('getty', 'imagesthe'): 1,
#          ('imagesthe', 'value'): 1,
#          ('value', 'bitcoin'): 1,
#          ('bitcoin', 'continued'): 1,
#          ('continued', 'fall'): 1,
#          ('fall', 'weekend'): 1,
#          ('weekend', 'dropped'): 1,
#          ('dropped', 'according'): 1,
#          ('according', 'coinbase'): 1,
#          ('coinbase', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'exchangethe'): 1,
#          ('exchangethe', 'worlds'): 1,
#          ('worlds', 'largest'): 1,
#          ('largest', 'cryp'): 1,
#          ('cryp', 'charssolana'): 1,
#          ('charssolana', 'third'): 1,
#          ('third', 'largest'): 1,
#          ('largest', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'market'): 1,
#          ('market', 'capitalization'): 1,
#          ('capitalization', 'fell'): 1,
#          ('fell', 'wednesday'): 1,
#          ('wednesday', 'following'): 1,
#          ('following', 'reports'): 1,
#          ('reports', 'blockchain'): 1,
#          ('blockchain', 'network'): 1,
#          ('network', 'suffering'): 1,
#          ('suffering', 'another'): 1,
#          ('another', 'outagethe'): 1,
#          ('outagethe', 'blockchain'): 1,
#          ('blockchain', 'produced'): 1,
#          ('produced', 'new'): 1,
#          ('new', 'block'): 1,
#          ('block', 'cryptocurrency'): 1,
#          ('ov', 'chars'): 1})

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
# YOUR CODE HERE!
top10_btc = token_count(btc_tokens, 10)
top10_btc
# Out:
# [('bitcoin', 11),
#  ('new', 9),
#  ('cryptocurrency', 8),
#  ('biggest', 5),
#  ('reuters', 5),
#  ('worlds', 4),
#  ('blockchain', 4),
#  ('luna', 4),
#  ('token', 4),
#  ('would', 3)]

# %%
# Use token_count to get the top 10 words for Ethereum
# YOUR CODE HERE!
top10_eth = token_count(eth_tokens, 10)
top10_eth
# Out:
# [('cryptocurrency', 11),
#  ('bitcoin', 7),
#  ('digital', 4),
#  ('reuters', 4),
#  ('market', 4),
#  ('worlds', 4),
#  ('years', 4),
#  ('new', 3),
#  ('us', 3),
#  ('ethereum', 3)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
# YOUR CODE HERE!
btc_list = str(top10_btc)
wordcloud = WordCloud(colormap="RdYlBu").generate(btc_list)
plt.imshow(wordcloud)
plt.axis("off")
fontdict = {"fontsize": 12, "fontweight": "bold"}
plt.title("BTC Top 10 Words", fontdict=fontdict)
plt.show()

# %%
# Generate the Ethereum word cloud
# YOUR CODE HERE!
eth_list = str(top10_eth)
wordcloud = WordCloud(colormap="RdYlBu").generate(eth_list)
plt.imshow(wordcloud)
plt.axis("off")
fontdict = {"fontsize": 12, "fontweight": "bold"}
plt.title("ETH Top 10 Words", fontdict=fontdict)
plt.show()

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
# YOUR CODE HERE!
btc_ner_text = ' '.join(btc_df['text'])
btc_ner_text
# Out:
# "New York lawmakers have passed a bill\r\n that would temporarily ban new bitcoin\r\n mining operations. Early on Friday, state senators voted 36-27 to pass the legislation. It's now bound for the desk of… [+2036 chars] Now, even though there are a number of women-focused crypto spaces, Odeniran says women are still underrepresented. Ive been in spaces where Im the only Black person, or the only woman, or the only B… [+3828 chars] A new study on bitcoin calls into question whether the digital currency is truly as decentralized and anonymous as its biggest devotees would have you believe. \r\n Researchers from Baylor, Rice, and t… [+7343 chars] Image caption, President Faustin-Archange Touadéra wants to rethink his country's economic philosophy\r\nThe Central African Republic's decision to adopt Bitcoin as legal tender came as a surprise to m… [+8881 chars] You can now reportedly pay for your burritos and tacos with Bitcoin and other digital currencies, in case you don't mind spending your coins directly instead of going through exchanges first. Flexa h… [+1428 chars] Image source, Getty Images\r\nThe value of Bitcoin continued to fall over the weekend as it dropped below $34,000 (£27,630), according to the Coinbase cryptocurrency exchange.\r\nThe world's largest cryp… [+2164 chars] As a kid, I remember when my father tried to use a broom handle in a last ditch effort to support a roof that was collapsing from the weight of nearly three feet of snow. You can guess how well that … [+3390 chars] Customers at Chipotle will now be able to pay for their burritos with cryptocurrencies, including bitcoin, ether, and dogecoin, in a move that could help crypto become more mainstream, according to t… [+3130 chars] Photo Illustration by Grayson Blackmon / The Verge; Photo by Oliyarnyk / CC-BY-SA-4.0\r\n\n \n\n\n With Michael Chobanian, the president of the Blockchain Association of Ukraine The terrible, unprovoked wa… [+52103 chars] Posted \r\nFrom Bitcoin's dramatic drop to a new way to pay for your luxury Gucci handbag, we round up the week's big stories in cryptocurrencies. Kristy Kilburn reports. May 11 (Reuters) - Bitcoin fell 7.23% to $28,758.29 at 22:05 GMT on Wednesday, losing $2,241.68 from its previous close.\r\nBitcoin, the world's biggest and best-known cryptocurrency, is down 40.4% fro… [+361 chars] May 9 (Reuters) - Bitcoin dropped 7.81% to $31,333.41 at 20:03 GMT on Monday, losing $2,655.98 from its previous close.\r\nBitcoin, the world's biggest and best-known cryptocurrency, is down 35% from t… [+351 chars] June 6 (Reuters) - Bitcoin rose 5.2% to $31,441.76 at 2000 GMT on Monday, adding $1,552.78 to its previous close.\r\nThe world's biggest and best-known cryptocurrency is down 34.8% from the year's high… [+335 chars] BTC fell to its lowest level since last July, as prices dropped below $33,000 to start the week. The selloff in cryptocurrency started last week, following the Fed’s decision to hike interest rates b… [+2651 chars] At a Mexican restaurant in North London a few weeks ago, a handful of small-time but remarkably discerning retail cryptocurrency investors predicted that terra and luna would crash. Several of them w… [+2779 chars] May 24 (Reuters) - The crypto winter is into its ninth week and bitcoin can't shake the chills.\r\nFrom technicals to turnover, market indicators are flashing red or amber for the biggest cryptocurrenc… [+3967 chars] May 10 (Reuters) - Bitcoin has scant experience with rising interest rates, posing perils for investors looking to capitalize on its dramatic drop.\r\nThe cryptocurrency has tanked along with other ris… [+4315 chars] Terra is launching a new blockchain with a new luna token. Seth Green's animated show starring his stolen NFT is up in the air. The largest stablecoin issuer in the world launched a token for the Mex… [+3792 chars] Terra launched a new blockchain with a new luna token, today. Seth Green's animated show starring his stolen NFT is up in the air. The largest stab ...

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!
btc_doc = nlp(btc_ner_text)
# Add a title to the document
# YOUR CODE HERE!
btc_doc.user_data["title"] = "Bitcoin - Named Entity Recognition"

# %%
# Render the visualization
# YOUR CODE HERE!
displacy.render(btc_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin - Named Entity Recognition</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br> mining operations. Early on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , state senators voted
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     36-27
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  to pass the legislation. It's now bound for the desk of… [+2036 chars] Now, even though there are a number of women-focused crypto spaces,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Odeniran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br> Researchers from Baylor, Rice, and t… [+7343 chars] Image caption, President
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Faustin-Archange Touadéra
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Central African Republic's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  decision to adopt
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  as legal tender came as a surprise to m… [+8881 chars] You can now reportedly pay for your burritos and tacos with Bitcoin and other digital currencies, in case you don't mind spending your coins directly instead of going through exchanges
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# . Flexa h… [+1428 chars] Image source,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Getty Images
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# The value of Bitcoin continued to fall over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the weekend
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  as it dropped below $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     34,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  (£
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     27,630
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# ), according to the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coinbase
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>The world's largest cryp… [
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     +2164
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  chars] As a kid, I remember when my father tried to use a broom handle in a last ditch effort to support a roof that was collapsing from the weight of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly three feet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  of snow. You can guess how well that … [+3390 chars] Customers at Chipotle will now be able to pay for their burritos with cryptocurrencies, including bitcoin, ether, and dogecoin, in a move that could help crypto become more mainstream, according to t… [+3130 chars
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ] Photo Illustration
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Grayson Blackmon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  / The Verge; Photo by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Oliyarnyk / CC-BY-SA-4.0
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br></br> </br></br></br> With
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michael Chobanian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the president of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Blockchain Association of Ukraine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>From
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's dramatic drop to a new way to pay for your luxury
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.2

# %%
# List all Entities
# YOUR CODE HERE!
for ent in btc_doc.ents:
    print(ent.text, ent.label_)
# Out:
# New York GPE
# Friday DATE
# 36-27 CARDINAL
# Odeniran GPE
# Faustin-Archange Touadéra LAW
# The Central African Republic's ORG
# Bitcoin NORP
# first ORDINAL
# Getty Images
#  ORG
# the weekend DATE
# 34,000 MONEY
# 27,630 MONEY
# Coinbase PERSON
# +2164 NORP
# nearly three feet QUANTITY
# ] Photo Illustration WORK_OF_ART
# Grayson Blackmon PERSON
# Oliyarnyk / CC-BY-SA-4.0 ORG
# Michael Chobanian PERSON
# the Blockchain Association of Ukraine ORG
# Bitcoin ORG
# Gucci handbag PERSON
# week DATE
# Kristy Kilburn PERSON
# May 11 DATE
# Reuters ORG
# 7.23% PERCENT
# 28,758.29 MONEY
# GMT WORK_OF_ART
# Wednesday DATE
# 2,241.68 MONEY
# 40.4% PERCENT
# May 9 DATE
# Reuters ORG
# 7.81% PERCENT
# 31,333.41 MONEY
# GMT WORK_OF_ART
# Monday DATE
# 2,655.98 MONEY
# 35% PERCENT
# Reuters ORG
# 5.2% PERCENT
# 31,441.76 MONEY
# GMT WORK_OF_ART
# Monday DATE
# 1,552.78 MONEY
# 34.8% PERCENT
# year DATE
# last July DATE
# 33,000 MONEY
# the week DATE
# last week DATE
# Fed ORG
# Mexican NORP
# North London LOC
# a few weeks ago DATE
# +2779 PERSON
# May 24 DATE
# Reuters ORG
# its ninth week DATE
# May 10 DATE
# Reuters ORG
# Seth Green's PERSON
# NFT ORG
# today DATE
# Seth Green's PERSON
# NFT ORG
# two CARDINAL
# Seth Green's PERSON
# Nike ORG

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
# YOUR CODE HERE!
eth_ner_text = ' '.join(eth_df['text'])
eth_ner_text
# Out:
# 'Meta has revealed more of how NFTs will work on Instagram. In the US-based test, you can show what you\'ve bought or created for free by connecting your Instagram account to a compatible digital walle… [+1223 chars] GameStop has officially thrown itself headlong into the web3 vipers nest with a new app release, though its hard to say whether its proposed population of gamers and game developers will take up the … [+3255 chars] The ability to conduct external transfers on PayPal\'s crypto platform, an image of which can be seen below, will start rolling out to users today and be available to everyone in the U.S. in the next … [+687 chars] GameStop is going all-in on crypto. The video game retailer launched\xa0its own self-custodial Ethereum digital wallet, it said Monday. The wallet will be accessible through a Google Chrome extension an… [+1491 chars] New York lawmakers have passed a bill\r\n that would temporarily ban new bitcoin\r\n mining operations. Early on Friday, state senators voted 36-27 to pass the legislation. It\'s now bound for the desk of… [+2036 chars] DAVOS, Switzerland, May 25 (Reuters) - Ethereum\'s co-founder Gavin Wood said cryptocurrency investors need to be more aware of what is backing their holdings after a market rout which wiped more than… [+1744 chars] Editorial IndependenceWe want to help you make more informed decisions. Some links on this page clearly marked may take you to a partner website and may result in us earning a referral commission. Fo… [+6022 chars] 40 days ago Bitcoin sold for $47,454. It\'s price now is $34,007 — a drop of 28%.About a third of that drop happened this week, as "Bitcoin, ethereum and other major cryptocurrencies have fallen sharp… [+975 chars] When Nvidia launched its Ampere Lite Hash Rate (LHR) graphics card with the feared Ethereum anti-mining limiter, the world knew it was only a matter of time before someone or a team cracked it. NiceH… [+1230 chars] May 11 (Reuters) - Bitcoin fell 7.23% to $28,758.29 at 22:05 GMT on Wednesday, losing $2,241.68 from its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is down 40.4% fro… [+361 chars] May 9 (Reuters) - Bitcoin dropped 7.81% to $31,333.41 at 20:03 GMT on Monday, losing $2,655.98 from its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is down 35% from t… [+351 chars] June 6 (Reuters) - Bitcoin rose 5.2% to $31,441.76 at 2000 GMT on Monday, adding $1,552.78 to its previous close.\r\nThe world\'s biggest and best-known cryptocurrency is down 34.8% from the year\'s high… [+335 chars] 9 with 8 posters participating\r\nNvidia began releasing LHR (or Lite Hash Rate) graphics cards last year\xa0to slow down their cryptocurrency mining performance and make them less appealing to non-gamers… [+2182 chars] BTC fell to its lowest level since last July, as prices dropped below $33,000 to start the week. The selloff in cryptocurrency started last week, following the Fed’s decision to hike interest rates b… [+2651 chars] The cryptocurrency boom over the past few years has helped propel a newer market to record heights: digital collectibles known as NFTs.\xa0\r\nThe craze has pushed total NFT sales volume to $29 billion ov… [+2866 chars] We first heard about the potential of blockchain in supply chains several years ago, and almost immediately were thrust into a cycle of hype and hope of what they could do for us, followed by a "trou… [+4785 chars] Every time you turn around, it seems another celebrity is hawking cryptocurrency or NFTs. Influencer Kim Kardashian, boxer Floyd Mayweather, and former NBA athlete Paul Pierce have all promoted Ether… [+2773 chars] Image source, Getty Images\r\nThe value of Bitcoin continued to fall over the weekend as it dropped below $34,000 (£27,630), according to the Coinbase cryptocurrency exchange.\r\nThe world\'s largest cryp… [+2164 chars] Solana, the third largest cryptocurrency by market capitalization, fell 10% Wednesday following r ...

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!
eth_doc = nlp(eth_ner_text)

# Add a title to the document
# YOUR CODE HERE!
eth_doc.user_data["title"] = "Ethereum - Named Entity Recognition"

# %%
# Render the visualization
# YOUR CODE HERE!
displacy.render(eth_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum - Named Entity Recognition</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Meta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has revealed more of how NFTs will work on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Instagram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . In the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -based test, you can show what you've bought or created for free by connecting your
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Instagram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  account to a compatible digital walle… [+1223 chars] GameStop has officially thrown itself headlong into the
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     web3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  vipers nest with a new app release, though its hard to say whether its proposed population of gamers and game developers will take up the … [+3255 chars] The ability to conduct external transfers on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PayPal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's crypto platform, an image of which can be seen below, will start rolling out to users
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and be available to everyone in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in the next … [+687 chars] GameStop is going all-in on crypto. The video game retailer launched its own self-custodial
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  digital wallet, it said
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The wallet will be accessible through a
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google Chrome
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  extension an… [+1491 chars]
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br> mining operations. Early on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , state senators voted
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     36-27
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  to pass the legislation. It's now bound for the desk of… [+2036 chars] DAVOS,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Switzerland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Ethereum's co-founder
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gavin Wood
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said cryptocurrency investors need to be more aware of what is backing their holdings after a market rout which wiped more than… [+1744 chars] Editorial IndependenceWe want to help you make more informed decisions. Some links on this page clearly marked may take you to a partner website and may result in us earning a referral commission. Fo… [+6022 chars] 40 days ago Bitcoin sold for $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     47,454
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . It's price now is $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     34,007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  — a drop of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     28%.About a third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of that drop happened
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; l

# %%
# List all Entities
# YOUR CODE HERE!
for ent in eth_doc.ents:
    print(ent.text, ent.label_)
# Out:
# Meta ORG
# Instagram ORG
# US GPE
# Instagram ORG
# web3 LOC
# PayPal ORG
# today DATE
# U.S. GPE
# Ethereum ORG
# Monday DATE
# Google Chrome PRODUCT
# New York GPE
# Friday DATE
# 36-27 CARDINAL
# Switzerland GPE
# May 25 DATE
# Reuters ORG
# Gavin Wood PERSON
# 47,454 MONEY
# 34,007 MONEY
# 28%.About a third CARDINAL
# this week DATE
# Nvidia PERSON
# Ampere Lite Hash Rate WORK_OF_ART
# LHR ORG
# Ethereum ORG
# May 11 DATE
# Reuters ORG
# 7.23% PERCENT
# 28,758.29 MONEY
# GMT WORK_OF_ART
# Wednesday DATE
# 2,241.68 MONEY
# 40.4% PERCENT
# May 9 DATE
# Reuters ORG
# 7.81% PERCENT
# 31,333.41 MONEY
# GMT WORK_OF_ART
# Monday DATE
# 2,655.98 MONEY
# 35% PERCENT
# Reuters ORG
# 5.2% PERCENT
# 31,441.76 MONEY
# GMT WORK_OF_ART
# Monday DATE
# 1,552.78 MONEY
# 34.8% PERCENT
# year DATE
# 9 CARDINAL
# 8 CARDINAL
# Nvidia ORG
# LHR ORG
# last year  DATE
# last July DATE
# 33,000 MONEY
# the week DATE
# last week DATE
# Fed ORG
# the past few years DATE
# NFT ORG
# $29 billion MONEY
# several years ago DATE
# Kim Kardashian PERSON
# Floyd Mayweather PERSON
# NBA ORG
# Paul Pierce PERSON
# Ether PERSON
# Getty Images
#  ORG
# the weekend DATE
# 34,000 MONEY
# 27,630 MONEY
# Coinbase PERSON
# +2164 NORP
# Solana PERSON
# third ORDINAL
# 10% PERCENT
# Wednesday DATE
# the past few years DATE
# NFT ORG
# $29 billion MONEY

# %% [markdown]
# ---
